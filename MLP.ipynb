# %%
import numpy

# %% [markdown]
# # The perceptron

# %%
X = numpy.array([[0,0],[0,1],[1,0],[1,1]])
X1,X2 = X[:,0],X[:,1]
y = numpy.array([[0],[1],[0],[1]])

# %%
X.shape,y.shape
# Out:
# ((4, 2), (4, 1))

# %% [markdown]
# ## Learning Rule
# $$
# w^{(next\ step)}_{i,j} = w_{i,j} - \eta(\hat{y_{j}}-y_{j})x_{i}
# $$

# %% [markdown]
# ![image.png](data:image/png;base64,...)
